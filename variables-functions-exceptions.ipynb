# %% [markdown]
# <h2> Variables, functions and exceptions </h2>

# %% [markdown]
# The `print()` method displays in your terminal the string set between the parentheses. Try changing the sentence of the following example and execute the cell to see the changes.

# %%
print('good afternoon friends!')

# %% [markdown]
# ----

# %% [markdown]
# <h3> Variables </h3>

# %% [markdown]
# #### Exercice 1
#
# Making use of the method print(), display the number 10 using the operators `+` and/or `*`.
# In other words, multiply or sum any combination of numbers to obtain number 10.

# %%
print(10)
# write here your code.

# %% [markdown]
# #### Exercice 2
#
# The `print` function is usually used as a debugger. In fact, it is possible to add multiple arguments to the method `print`, cada each of them separated with a comma. Display the following message:
# ```
# 3 + 4, 'should be equals to 7'
# ```

# %%
# write here your code.

# %% [markdown]
# #### Exercice 3
#
# Concatenate two strings using the `+` operator and display your name and surname.

# %%
print('Code' + 'Op') # change this line

# %% [markdown]
# #### Exercice 4
#
# Use the module `%` operator to determine whether a number is even or odd. How can you check this?

# %%
# write here your code

# %% [markdown]
# #### Exercice 5
#
# Change Mia's location reassigning the variable `location` with a new string. Do it in a new line, and avoid deleting any already written line. Delete the hashtag `#` of the last line tu uncomment the code and print the message.

# %%
name = 'Mia'
location = 'school'
# write your code here
# print(name + ' is ' + location)

# %% [markdown]
# #### Exercice 6
#
# Create the necessary variables to print the following message:

# %%
# write your code here
print(person, 'went to', place, 'to eat', food)

# %% [markdown]
# #### Exercice 7
#
# Reassign all of the previous variables to print a novel message:

# %%
# escriu el teu codi aquí
print(person, 'went to', place, 'to eat', food)

# %% [markdown]
# #### Exercice 8
#
# There are different ways to increment the variable `count`. What is the result of executing the following 4 lines of code? Write in a comment after each line using the `#` operator to indicate the value of the variable `count`
#
# *Hint: look up what += does if it's not clear!*

# %%
count = 0
count = count + 1
count += 1
count += count

# %% [markdown]
# #### Exercice 9
#
# Time for sharing! In the following code, we want to exchange the values of `a` and `b`. The code written below does not work. To solve this exercice, you will need to create an additional variable (you can name it `temp`) to store the value of `a` or `b` while you change its value. Try drawing if you don't see it clear!

# %%
a = 1
b = 2

# %%
print('BEFORE > a was:', a, '- i b was: ', b)

# %%
# write your code here

# %%
print('AFTER > a:', a, 'has to be 2 - and b:', b, 'has to be 1')

# %% [markdown]
# #### Exercice 10
#
# What will be the result of the following code? Try different combinations in order to make the boolean True.
#
# *Hint: you might want to convert an integer into a string, or a string into a integer...*

# %%
print(3 == '3', 'should be True')

# %% [markdown]
# ----

# %% [markdown]
# <h3> Functions </h3>

# %% [markdown]
# #### Exercice 1
#
# Define a function named `triple` with an input variable `x` that returns its value multiplied by 3.

# %%
# write your code here

# %% [markdown]
# #### Exercice 2
#
# Define a function named `subtraction` with you input variables that returns the difference between the second and the first value.

# %%
# write your code here

# %% [markdown]
# #### Exercice 3
#
# Define a function that returns the volume of a cube knowing how long the edge is.
#
# *Note: $V=c^3$, where $V$ is the volume and $c$ is the length of the cube's edge.*

# %%
# write your code here

# %% [markdown]
# #### Exercice 4
#
# Define a variable named `total` and assign to it a 0 value. Then, define a function named `my_sum` with two input variables. This function has to sum both values and assign the result of the sum to the variable `total` inside the function. Print the value of `total` inside and outside the function and see the difference in results.

# %%
# write here your code

# %% [markdown]
# ----

# %% [markdown]
# <h3> Exceptions </h3>

# %% [markdown]
# #### Exercice 1
#
# Without executing the code, would you know the output of the following code?

# %%
def fn(x):
    try:
        print(5/x)
    except:
        print('Error ocurred')
fn(0)

# %% [markdown]
# #### Exercice 2
#
# Define a function named `division` with two input variables: numerator and denominator. Create an exception when the denominator is equal to 0 and, instead of printing an error, print the following message:
#
# ```python
# 'the denominator of a function cannot be 0'
# ```

# %%
# write here your code

# %% [markdown]
# #### Exercice 3
#
# Define a function named `safe_subtractor` with two input parameters that returns the difference between the second parameter and the first. If the values cannot be subtracted, it returns `None`.

# %%
# write here your code

# %% [markdown]
# #### Exercice 4
#
# Define a function named `saluda_persona` that takes as input value a 'string' representing the name of a person. The function has to return the string composed in a longer sentence. For example:
#
# ```python
# saluda_persona('Sophia') -> 'Hola, Sophia!'
# ```
#
# If the input parameter is not a string, an exception should be raised with the following message: 'Please, give me a name.':
#
# ```python
# saluda_persona(5) -> Exeception: 'Please, give me a name'
# ```

# %%
# write here your code
